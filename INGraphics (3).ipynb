# %%
# We tend to abbreviate the pandas library as pd
import pandas as pd
import matplotlib.pyplot as plt
# Stop pandas from abbreviating tables to fit in the notebook
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000
# Display graphs in the notebook
# %matplotlib inline

# %%
# read in our csv file, and automatically change missing values (a dot in the csv) into NaN
boroughs = pd.read_csv('boroughs.csv', na_values = ['.',' '])
# Use the head function to see the amount of rows wanted in the brackets
alls = boroughs.head(len(boroughs))#This means that all the rows are included because the len(boroughs) means the length of boroughs so all of these values will be set to alls
boroughs = boroughs.head(len(boroughs)-5)#These are all the values except UK, England, London, InnerLondon, OuterLondon and these values are set to boroughs

# %%
boroughs = boroughs.set_index(boroughs.Borough) # This makes the numbers for the first column become replaced by the boroughs instead and sets the values back to boroughs

# %%
boroughs = boroughs.sort_values("UnemployY") # This makes the spreadsheet be sorted by the value from unemployed youths instead of being sorted alphabetically by the boroughs

# %%
boroughs[['InnerOuter','Population','LT15','GCSEs','UnemployY','Jobs','NEET']] #This shows the varibles that we wanted to see from the dataset so it is focused on what we need only
# Out:
#                           InnerOuter  Population  LT15  GCSEs  UnemployY  \
# Borough
# City of London          Inner London        8800  11.4   78.6        1.6
# Barnet                  Outer London      389600  21.1   67.3        1.9
# Kingston upon Thames    Outer London      175400  19.6   68.6        2.0
# Hammersmith and Fulham  Inner London      185300  17.4   60.5        2.2
# Sutton                  Outer London      202600  20.7   67.4        2.3
# Richmond upon Thames    Outer London      197300  20.7   70.5        2.4
# Harrow                  Outer London      252300  20.5   66.4        2.4
# Hillingdon              Outer London      301000  21.3   62.0        2.5
# Bromley                 Outer London      327900  19.9   68.0        2.5
# Wandsworth              Inner London      321000  17.8   63.0        2.6
# Bexley                  Outer London      244300  20.6   60.3        2.9
# Hounslow                Outer London      274200  21.1   63.2        2.9
# Ealing                  Outer London      351600  21.4   62.1        3.0
# Brent                   Outer London      332100  20.9   60.1        3.1
# Tower Hamlets           Inner London      304000  20.1   59.2        3.2
# Havering                Outer London      254300  19.3   59.8        3.3
# Enfield                 Outer London      333000  22.8   59.9        3.3
# Kensington and Chelsea  Inner London      159000  16.4   68.7        3.4
# Westminster             Inner London      242100  15.9   65.7        3.5
# Waltham Forest          Outer London      276200  21.8   58.3        3.5
# Camden                  Inner London      242500  17.3   62.7        3.6
# Merton                  Outer London      208100  20.6   67.8        3.9
# Lambeth                 Inner London      328900  17.6   57.1        4.1
# Newham                  Inner London      342900  22.7   55.7        4.1
# Redbridge               Outer London      304200  22.8   68.7        4.1
# Islington               Inner London      231200  15.9   59.9        4.5
# Barking and Dagenham    Outer London      209000  27.2   58.0        4.5
# Southwark               Inner London      314300  18.6   61.2        4.7
# Hackney                 Inner London      274300  20.7   60.6        4.8
# Croydon                 Outer London      386500  22.0   57.7        4.8
# Greenwich               Outer London      280100  21.9   58.8        5.4
# Haringey                Inner London      278000  20.0   59.7        5.6
# Lewisham                Inner London      303400  20.6   56.3        6.0
#
#                             Jobs  NEET
# Borough
# City of London          500400.0   NaN
# Barnet                  167300.0   2.5
# Kingston upon Thames     83700.0   3.9
# Hammersmith and Fulham  149500.0   2.5
# Sutton                   78600.0   3.2
# Richmond upon Thames     95900.0   4.3
# Harrow                   88600.0   1.5
# Hillingdon              220900.0   2.4
# Bromley                 127800.0   4.3
# Wandsworth              134100.0   2.9
# Bexley                   80700.0   3.4
# Hounslow                165700.0   3.2
# Ealing                  160500.0   3.0
# Brent                   133600.0   2.6
# Tower Hamlets           280100.0   3.4
# Havering                 91300.0   4.0
# Enfield                 128800.0   3.1
# Kensington and Chelsea  143500.0   3.6
# Westminster             730700.0   2.2
# Waltham Forest           84500.0   3.0
# Camden                  377400.0   4.4
# Merton                   96800.0   4.3
# Lambeth                 184000.0   2.2
# Newham                  111100.0   4.3
# Redbridge                90700.0   3.3
# Islington               231500.0   5.2
# Barking and Dagenham     58900.0   5.7
# Southwark               285900.0   2.0
# Hackney                 132800.0   3.0
# Croydon                 141600.0   3.3
# Greenwich                94700.0   5.0
# Haringey                 91500.0   3.5
# Lewisham                 90000.0   3.5

# %%
# pyplot is the grandparent of all python plotting packages
import matplotlib.pyplot as plt
# seaborn is based on pyplot but makes it easier to use
import seaborn as sns
# Abbreviate seaborn as sns to make easier to write it

# %%
boroughs.GCSEs.corr(boroughs.UnemployY) # This shows the correlation coefficient between GCSEs and youth unemployment
# Out:
# -0.6215731992860181

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax1 = fig.add_subplot(111)
colour = boroughs["Population"]
x1 = boroughs['GCSEs']
y1 = boroughs["UnemployY"]
size=boroughs["NEET"]

ax1.scatter(x1, y1, s=60, c=colour)

# %%
# by default seaborn plots come out a bit small, so make ours 8in by 8in
plt.figure(figsize=(8,8))
# sns.scatterplot has options for controlling colour and dot size so we can use four variables on one graph
sns.scatterplot(x=boroughs['GCSEs'],
                y=boroughs["UnemployY"],
                size=boroughs["NEET"],
                sizes=(50,200),
                hue=boroughs["Population"],
                marker= "^",
                palette="Blues")
# where to put the legend
plt.legend(loc='upper right');

# %%
y = boroughs['GCSEs']
z = boroughs["UnemployY"]
n = boroughs["Borough"]

fig, ax = plt.subplots()
ax.scatter(z, y)

for i, txt in enumerate(n):
    ax.annotate(txt, (z[i], y[i]))
